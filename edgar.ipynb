# %%
from edgar import get_filings, set_identity

# %%
set_identity("larrym.shan@gmail.com")

# %%
filings = get_filings(year=2024, form="S-1")
filings
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭────────────────────────────────────────────────── SEC Filings ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                            Filing                               │
# │    Form              CIK   Tick…   Company                                 Date         Accession Number        │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │    S-1           2033750           AEN Group Ltd.                          2024-12-31   0001640334-24-001…      │
# │    S-1           1655923   ACOG    Alpha Cognition Inc.                    2024-12-31   0001213900-24-114…      │
# ...
